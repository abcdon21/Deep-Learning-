# %% [markdown]
# <a href="https://colab.research.google.com/github/abcdon21/Deep-Learning-/blob/main/ImportingDatasetFromKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CONNECTING GOOGLE DRIVE AND KAGGLE TO UPLOAD FILES

# %%
# !pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/KaggleAPI/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle kernels pull arbazkhan971/image-classification-using-cnn-94-accuracy
# Out:
# Source code downloaded to /content/image-classification-using-cnn-94-accuracy.ipynb

# %%
! kaggle datasets download arbazkhan971/image-classification-using-cnn-94-accuracy
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata

# %% [markdown]
# IMPORT API

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("puneet6060/intel-image-classification")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'intel-image-classification' dataset.
# Path to dataset files: /kaggle/input/intel-image-classification

# %%
X= '/kaggle/input/intel-image-classification/seg_train/seg_train'

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1178/4157383958.py in <cell line: 0>()
#       2
#       3 np.random.seed(42)
# ----> 4 tf.random.set_seed(42)
#
# NameError: name 'tf' is not defined
