# %% [markdown]
# <a href="https://colab.research.google.com/github/abcdon21/Deep-Learning-/blob/main/DeepLearning_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cc_churn.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# nomial encoding on gender and geography because its categorial

# %%
df=pd.get_dummies(df,columns=['Gender', 'Geography'],drop_first=True)

# %%
X= df.drop(['RowNumber','CustomerId','Surname','Exited'],axis=1)

# %%
y=df['Exited']

# %% [markdown]
# Splitting dataset

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# Standard Scaling in neural network

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# # NEURAL NETWORK
# tensor flow library with kera

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#input layer
model.add(Input(shape=(11,)))

#hidden layer 1( in tensor flow refered as dense)
model.add(Dense(128,activation='relu'))

# hidden layer 2
model.add(Dense(units=64,activation='relu'))

#output layer
model.add(Dense(units=1,activation='sigmoid')) # sigmoid function ranges the output between 0 to 1 in binary classification sigmoid function is used in the output layer

# %%
# 1 neuron has 11 weights(11 features)
# 123 neurons would have 11 x 128 weights = 1408
# + each neuron would have 1 bias  = 128 biases

# total = 1408+128 = 1536

# now this time input=128
# total=128*64+64=8256

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,857 (38.50 KB)
#  Trainable params: 9,857 (38.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', metrics=['accuracy'])  #after completeing architecture of layers combines all the layers

# %%
# ->early stopping
earlystop=EarlyStopping(monitor='val_loss',patience=5, restore_best_weights=True)

# %% [markdown]
# TRAIN THE MODEL

# %%
model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test),callbacks=earlystop) #epochs decides the number of back propogation
#validation accuracy
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8232 - loss: 0.4183 - val_accuracy: 0.8570 - val_loss: 0.3675
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8500 - loss: 0.3618 - val_accuracy: 0.8615 - val_loss: 0.3485
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8580 - loss: 0.3467 - val_accuracy: 0.8650 - val_loss: 0.3423
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8619 - loss: 0.3399 - val_accuracy: 0.8610 - val_loss: 0.3399
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8625 - loss: 0.3376 - val_accuracy: 0.8490 - val_loss: 0.3514
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8625 - loss: 0.3328 - val_accuracy: 0.8620 - val_loss: 0.3397
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8624 - loss: 0.3305 - val_accuracy: 0.8595 - val_loss: 0.3419
# Epoch 8/10
# ...

# %%
# stopping at the point which give best possible accuracy (early stopping) - gradial descent
from tensorflow.keras.callbacks import EarlyStopping

# %%
y_pred= model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import classification_report
rep= classification_report(y_test,y_pred.round())
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1595
#            1       0.74      0.49      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
